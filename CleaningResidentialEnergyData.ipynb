# %%
# Import Dependencies 
import matplotlib.pyplot as plt
import numpy as np
import os
import csv
import pandas as pd

# %%
# Store filepath in a variable
hourly_residential = "Resources/HourlyResidential.csv"

# Import API keys
import api_keys as api_key

# %%
# Read our Data file with the pandas library
# Not every CSV requires an encoding, but be aware this can come up
hourly_residential_df = pd.read_csv(hourly_residential, header=None)

# %%
# Show just the header
hourly_residential_df.head()
# Out:
#                                                    0          1            2  \
# 0  # Please note that there may be discrepancies ...        NaN          NaN
# 1                                           DateTime  Device ID         Name
# 2                                      3/1/2020 0:00      mains  Total Usage
# 3                                      3/1/2020 0:00  always_on    Always On
# 4                                      3/1/2020 0:00   cfd74978      Furnace
#
#              3            4             5                6            7      8
# 0          NaN          NaN           NaN              NaN          NaN    NaN
# 1  Device Type  Device Make  Device Model  Device Location  Avg Wattage    kWh
# 2          NaN          NaN           NaN              NaN     1247.115  1.247
# 3     AlwaysOn          NaN           NaN              NaN          407  0.407
# 4      Furnace          NaN           NaN              NaN      341.049  0.341

# %%
hourly_residential_df.drop([0,0])
# Out:
#                     0          1                 2             3            4  \
# 1            DateTime  Device ID              Name   Device Type  Device Make
# 2       3/1/2020 0:00      mains       Total Usage           NaN          NaN
# 3       3/1/2020 0:00  always_on         Always On      AlwaysOn          NaN
# 4       3/1/2020 0:00   cfd74978           Furnace       Furnace          NaN
# 5       3/1/2020 0:00      solar  Solar Production         Solar          NaN
# ...               ...        ...               ...           ...          ...
# 4456  3/31/2020 23:00   77639ae9   Portable Heater  Space Heater          NaN
# 4457    4/1/2020 0:00      mains       Total Usage           NaN          NaN
# 4458    4/1/2020 0:00  always_on         Always On      AlwaysOn          NaN
# 4459    4/1/2020 0:00      solar  Solar Production         Solar          NaN
# 4460    4/1/2020 0:00   77639ae9   Portable Heater  Space Heater          NaN
#
# ...

# %%
hourly_residential_df.loc['1':'Device Type']
# Out:
#                     0          1                 2             3            4  \
# 1            DateTime  Device ID              Name   Device Type  Device Make
# 2       3/1/2020 0:00      mains       Total Usage           NaN          NaN
# 3       3/1/2020 0:00  always_on         Always On      AlwaysOn          NaN
# 4       3/1/2020 0:00   cfd74978           Furnace       Furnace          NaN
# 5       3/1/2020 0:00      solar  Solar Production         Solar          NaN
# ...               ...        ...               ...           ...          ...
# 4456  3/31/2020 23:00   77639ae9   Portable Heater  Space Heater          NaN
# 4457    4/1/2020 0:00      mains       Total Usage           NaN          NaN
# 4458    4/1/2020 0:00  always_on         Always On      AlwaysOn          NaN
# 4459    4/1/2020 0:00      solar  Solar Production         Solar          NaN
# 4460    4/1/2020 0:00   77639ae9   Portable Heater  Space Heater          NaN
#
# ...

# %%
hourly_residential_df2 = hourly_residential_df.T.drop_duplicates([0])
del hourly_residential_df2[1]
hourly_residential_df2
# Out:
#                                                 0              2     \
# 0  # Please note that there may be discrepancies ...  3/1/2020 0:00
# 1                                                NaN          mains
#
#             3              4              5              6              7     \
# 0  3/1/2020 0:00  3/1/2020 0:00  3/1/2020 0:00  3/1/2020 0:00  3/1/2020 0:00
# 1      always_on       cfd74978          solar       63b2178f       77639ae9
#
#             8              9              10    ...             4451  \
# 0  3/1/2020 0:00  3/1/2020 0:00  3/1/2020 1:00  ...  3/31/2020 22:00
# 1       IQP6F3DS       hgLq1FnZ          mains  ...            solar
#
#               4452             4453             4454             4455  \
# 0  3/31/2020 23:00  3/31/2020 23:00  3/31/2020 23:00  3/31/2020 23:00
# 1            mains        always_on         c4efa971            solar
#
#               4456           4457           4458           4459           4460
# ...

# %%
hourly_residential_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4461 entries, 0 to 4460
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       4461 non-null   object
#  1   1       4460 non-null   object
#  2   2       4460 non-null   object
#  3   3       3716 non-null   object
#  4   4       1 non-null      object
#  5   5       1 non-null      object
#  6   6       1 non-null      object
#  7   7       4460 non-null   object
#  8   8       4460 non-null   object
# dtypes: object(9)
# memory usage: 313.8+ KB

# %%
hourly_residential_df.columns
# Out:
# Int64Index([0, 1, 2, 3, 4, 5, 6, 7, 8], dtype='int64')

# %%
# Show mulitple specific columns
# hourly_residential_df[["Unnamed: 2", "Unnamed: 3"]].head()

# %%
# Files to load and output 
file_to_load = os.path.join("Resources", "HourlyResidential.csv")
file_to_output = os.path.join("Analysis", "HourlyAnalysis.txt")
